# %% [markdown]
# # **Import Library**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Data Sets**

# %%
date =pd.read_csv('/content/orders.csv')
time =pd.read_csv('/content/messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %% [markdown]
# # **information**

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# # **Working with Dates**

# %%
#converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# # **1. Extract year**

# %%
date['date_year'] = date['date'].dt.year

date.sample(5)

# %%
date['date_year'] = date['date'].dt.year

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year
# 957 2019-07-12        5250        3       9       2019
# 398 2019-07-19        2307        4       9       2019
# 535 2019-10-26        7318       25       1       2019
# 204 2018-10-07         820       30       2       2018
# 72  2018-08-27        7582       17      30       2018

# %% [markdown]
# # **2. Extract Month**

# %%
date['date_month_no'] = date['date'].dt.month

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no
# 73  2019-07-28        3913       13      19       2019              7
# 471 2018-11-05        6430       13       1       2018             11
# 236 2018-08-24        4576       22       3       2018              8
# 765 2018-11-01        3913       13       7       2018             11
# 946 2018-11-10        6309       29      11       2018             11

# %% [markdown]
# # **3.Extract Month name**

# %%
date['date_month_name'] = date['date'].dt.month_name()

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 820 2019-07-27        7239       22       2       2019              7
# 165 2018-12-05         327       17       2       2018             12
# 393 2019-05-19        2271        3      28       2019              5
# 222 2019-01-22        5002       13      15       2019              1
# 390 2018-11-04        7526       14       5       2018             11
#
#     date_month_name
# 820            July
# 165        December
# 393             May
# 222         January
# 390        November

# %% [markdown]
# # **4.Extract Days**

# %%
date['date_day']= date['date'].dt.day

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 933 2019-07-04        7138       28       3       2019              7
# 281 2019-06-17        4379        4       1       2019              6
# 774 2019-08-17        2459        0       8       2019              8
# 583 2019-05-17        2589       20       2       2019              5
# 334 2019-10-27        1130       14      48       2019             10
#
#     date_month_name  date_day
# 933            July         4
# 281            June        17
# 774          August        17
# 583             May        17
# 334         October        27

# %% [markdown]
# # **5. Day of Weeks**

# %%
# day of week
date['date_dow'] = date['date'].dt.dayofweek

date.head()

# %%
#day of week
date['date_of_week'] =date['date'].dt.dayofweek

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 165 2018-12-05         327       17       2       2018             12
# 984 2019-11-23         528        0       3       2019             11
# 160 2019-11-28        2627       16       1       2019             11
# 771 2019-06-17        2897       26       1       2019              6
# 978 2018-11-13        2845       23       2       2018             11
#
#     date_month_name  date_day  date_of_week
# 165        December         5             2
# 984        November        23             5
# 160        November        28             3
# 771            June        17             0
# 978        November        13             1

# %% [markdown]
# # **6.Day of Week Name**

# %%
#day of week name

date['date_of_week_name'] =date['date'].dt.day_name()

date.drop(columns=['product_id', 'city_id', 'orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#    date_of_week date_of_wee_name date_of_week_name
# 0             1          Tuesday           Tuesday
# 1             2        Wednesday         Wednesday
# 2             1          Tuesday           Tuesday
# 3             5         Saturday          Saturday
# 4             6           Sunday            Sunday

# %% [markdown]
# # **day of weekend**

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_of_week_name'].isin(['Sunday', 'Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#    date_of_week  date_of_wee_name date_of_week_name  date_is_weekend  \
# 0            50                50           Tuesday                0
# 1            33                33         Wednesday                0
# 2            43                43           Tuesday                0
# 3            33                33          Saturday                1
# 4             1                 1            Sunday                1
#
#    date_week  quarter  semester
# 0         50        4         2
# 1         33        3         2
# 2         43        4         2
# 3         33        3         2
# 4          1        1         1

# %% [markdown]
# # **Extract week of the year**

# %%
date['date_week'] = date['date'].dt.week

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
# <ipython-input-40-47b3fbf1eb9c>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['date_week'] = date['date'].dt.week
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#    date_of_week  date_of_wee_name date_of_week_name  date_is_weekend  \
# 0            50                50           Tuesday                0
# 1            33                33         Wednesday                0
# 2            43                43           Tuesday                0
# 3            33                33          Saturday                0
# 4             1                 1            Sunday                0
#
#    date_week
# 0         50
# 1         33
# 2         43
# 3         33
# 4          1

# %% [markdown]
# # **Extract Quarter**

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id', 'city_id', 'orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#    date_of_week  date_of_wee_name date_of_week_name  date_is_weekend  \
# 0            50                50           Tuesday                0
# 1            33                33         Wednesday                0
# 2            43                43           Tuesday                0
# 3            33                33          Saturday                0
# 4             1                 1            Sunday                0
#
#    date_week  quarter
# 0         50        4
# 1         33        3
# 2         43        4
# 3         33        3
# 4          1        1

# %% [markdown]
# # **Extract semester**

# %%
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()

# %%
date['semester'] =np.where(date['quarter'].isin([1,2]), 1,2)
date.drop(columns=['product_id', 'city_id', 'orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#    date_of_week  date_of_wee_name date_of_week_name  date_is_weekend  \
# 0            50                50           Tuesday                0
# 1            33                33         Wednesday                0
# 2            43                43           Tuesday                0
# 3            33                33          Saturday                0
# 4             1                 1            Sunday                0
#
#    date_week  quarter  semester
# 0         50        4         2
# 1         33        3         2
# 2         43        4         2
# 3         33        3         2
# 4          1        1         1

# %% [markdown]
# # **Extract Time elapsed between dates**

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2024, 3, 31, 11, 7, 6, 377118)

# %%
today - date['date']
# Out:
# 0     1573 days 11:07:06.377118
# 1     2055 days 11:07:06.377118
# 2     1986 days 11:07:06.377118
# 3     1688 days 11:07:06.377118
# 4     1911 days 11:07:06.377118
#                  ...
# 995   2001 days 11:07:06.377118
# 996   1942 days 11:07:06.377118
# 997   1790 days 11:07:06.377118
# 998   1855 days 11:07:06.377118
# 999   1629 days 11:07:06.377118
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      1573
# 1      2055
# 2      1986
# 3      1688
# 4      1911
#        ...
# 995    2001
# 996    1942
# 997    1790
# 998    1855
# 999    1629
# Name: date, Length: 1000, dtype: int64

# %% [markdown]
# # **Months Passed**

# %%
# Months passed

np.round((today -date['date']) / np.timedelta64(1, 'M'),0)

# %%
# Months passed

np.round((today -date['date'])/ np.timedelta64(1,'M'), 0)
# Out:
# 0      52.0
# 1      68.0
# 2      65.0
# 3      55.0
# 4      63.0
#        ...
# 995    66.0
# 996    64.0
# 997    59.0
# 998    61.0
# 999    54.0
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# # **Time Data sets**

# %%
time
# Out:
#                     date                                                msg
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # **Convert the Data Type**

# %%
#converting to datetime datatype
time['date'] =pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %% [markdown]
# # **Extract hour in time dataset**

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()

# %%
time['hour'] = time['date'].dt.hour
time['min']= time['date'].dt.minute
time['sec'] =time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %% [markdown]
# # **Extract the time**

# %%
time['time'] =time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %% [markdown]
# # **Time difference**

# %%
today - time['date']
# Out:
# 0     3759 days 10:17:06.377118
# 1     3623 days 11:27:06.377118
# 2     4109 days 10:46:06.377118
# 3     3411 days 10:36:06.377118
# 4     3808 days 11:56:06.377118
#                  ...
# 995   4398 days 10:17:06.377118
# 996   3719 days 11:53:06.377118
# 997   4184 days 11:30:06.377118
# 998   4300 days 11:33:06.377118
# 999   3572 days 11:42:06.377118
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %% [markdown]
# # **In Second**

# %%
(today -time ['date']) / np.timedelta64(1,'s')
# Out:
# 0      3.248146e+08
# 1      3.130684e+08
# 2      3.550564e+08
# 3      2.947486e+08
# 4      3.290542e+08
#            ...
# 995    3.800242e+08
# 996    3.213644e+08
# 997    3.615390e+08
# 998    3.715616e+08
# 999    3.086629e+08
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# # **In Minutes**

# %%
(today - time['date']) / np.timedelta64(1,'m')
# Out:
# 0      5.413577e+06
# 1      5.217807e+06
# 2      5.917606e+06
# 3      4.912476e+06
# 4      5.484236e+06
#            ...
# 995    6.333737e+06
# 996    5.356073e+06
# 997    6.025650e+06
# 998    6.192693e+06
# 999    5.144382e+06
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# # **Hours**

# %%
(today - time ['date']) / np.timedelta64(1,'h')
# Out:
# 0       90226.285105
# 1       86963.451771
# 2       98626.768438
# 3       81874.601771
# 4       91403.935105
#            ...
# 995    105562.285105
# 996     89267.885105
# 997    100427.501771
# 998    103211.551771
# 999     85739.701771
# Name: date, Length: 1000, dtype: float64
